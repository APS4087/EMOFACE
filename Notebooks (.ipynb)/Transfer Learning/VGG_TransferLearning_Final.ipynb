# %% [markdown]
# # **Importing Necessary Libiary**

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.multiprocessing as mp
from torch.utils.data import DataLoader, WeightedRandomSampler
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import ParameterGrid

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device

# Set the start method to 'spawn'
mp.set_start_method('spawn')

# %% [markdown]
# # **Loading Dataset**

# %%
# Load the dataset
transform = transforms.Compose(
    [transforms.Grayscale(num_output_channels=1),
     transforms.Resize((128, 128)),
     transforms.ToTensor(),
     transforms.Normalize((0.5,), (0.5,))])

trainset = torchvision.datasets.ImageFolder(root='./../fer2013plus/fer2013/train', transform=transform)
testset = torchvision.datasets.ImageFolder(root='./../fer2013plus/fer2013/test', transform=transform)

# check data shape
from collections import Counter
# Count the number of samples per class in the training set
train_labels = [trainset[i][1] for i in range(len(trainset))]
train_counter = Counter(train_labels)

# Count the number of samples per class in the test set
test_labels = [testset[i][1] for i in range(len(testset))]
test_counter = Counter(test_labels)

class_names = trainset.classes
print(class_names)

# Print the distribution
print("Training set class distribution:")
for i, class_name in enumerate(class_names):
    print(f'{class_name:5s}: {train_counter[i]}')

print("\nTest set class distribution:")
for i, class_name in enumerate(class_names):
    print(f'{class_name:5s}: {test_counter[i]}')

total_samples = len(trainset)

# Calculate class weights based on the training set distribution
class_weights = {class_id: total_samples / count for class_id, count in train_counter.items()}
class_weights_list = [class_weights[label] for label in train_labels]
print(class_weights)
print(len(class_weights_list))

# Create a WeightedRandomSampler
sampler = WeightedRandomSampler(class_weights_list, len(class_weights_list), replacement=True, )

# Create data loaders
train_loader = DataLoader(trainset, batch_size=64, sampler=sampler)
test_loader = DataLoader(testset, batch_size=64, shuffle=False)
# Out:
# ['anger', 'contempt', 'disgust', 'fear', 'happiness', 'neutral', 'sadness', 'surprise']
# Training set class distribution:
# anger: 2466
# contempt: 165
# disgust: 191
# fear : 652
# happiness: 7528
# neutral: 10308
# sadness: 3514
# surprise: 3562
#
# Test set class distribution:
# anger: 644
# contempt: 51
# disgust: 57
# fear : 167
# happiness: 1827
# neutral: 2597
# sadness: 856
# surprise: 900
# {0: 11.510948905109489, 1: 172.03636363636363, 2: 148.61780104712042, 3: 43.53680981595092, 4: 3.770722635494155, 5: 2.7537834691501746, 6: 8.077973819009676, 7: 7.969118472768108}
# 28386

# %% [markdown]
# # **VGG Model**

# %%
# Define the model
# Dataset image size is 48x48 => 128x128

# Adding another convolutional layer block (total of 5 blocks)

class TinyVGG5(nn.Module):
    def __init__(self, num_classes):
        super(TinyVGG5, self).__init__()

        self.conv_layers = nn.Sequential(
            # Convolutional Layer Block 1
            nn.Conv2d(1, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), # 128 -> 64

            # Convolutional Layer Block 2
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), # 64 -> 32

            # Convolutional Layer Block 3
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), # 32 -> 16

            # Convolutional Layer Block 4
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), # 16 -> 8

            # Convolutional Layer Block 5
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), # 8 -> 4
        )

        self.fc_layers = nn.Sequential(
            nn.Linear(512 * 4 * 4, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = x.view(x.size(0), -1)
        x = self.fc_layers(x)
        return x

# %% [markdown]
# # **Loading State Dictionary**

# %%
# Load the state dictionary
state_dict = torch.load('tiny_VGG.pth')

# %%
# define train and validation as a funcnion

def train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs=10):
    model = model.to(device)
    # Track metrics
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    # Training loop
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward pass and optimize
            loss.backward()
            optimizer.step()

            # Print statistics
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        avg = running_loss / len(train_loader)
        train_losses.append(avg)
        train_accuracies.append(100 * correct / total)

        # Validation
        model.eval()
        running_loss = 0.0
        correct = 0
        total = 0
        all_preds = []
        all_labels = []

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                running_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                all_preds.extend(predicted.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

        val_losses.append(running_loss / len(test_loader))
        val_accuracies.append(100 * correct / total)

        print(f'Epoch {epoch + 1}/{num_epochs}, train Loss: {train_losses[-1]:.4f}, train Acc: {train_accuracies[-1]:.2f}%, validation Loss: {val_losses[-1]:.4f}, validation Acc: {val_accuracies[-1]:.2f}%')

    return train_losses, val_losses, train_accuracies, val_accuracies, all_preds, all_labels

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# plot training and validation loss
# Plotting the results
def plot_results(train_losses, val_losses, train_accuracies, val_accuracies, num_epochs, all_preds, all_labels):
    epochs = range(1, num_epochs + 1)

    plt.figure(figsize=(12, 5))

    # Plot training and validation loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, 'bo-', label='Training Loss')
    plt.plot(epochs, val_losses, 'ro-', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot training and validation accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, 'bo-', label='Training Accuracy')
    plt.plot(epochs, val_accuracies, 'ro-', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

    # Confusion matrix
    # Compute confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=trainset.classes)

    # Plot confusion matrix
    disp.plot(cmap=plt.cm.Blues)
    plt.show()

# %% [markdown]
# # **Hyperparameter Tuning**

# %% [markdown]
# ## Freeze all layers except the final layer

# %%
# Transfer Learning with Hyperparameter Tuning

param_grid = {
    'lr': [1e-4, 1e-5],
    'batch_size': [32, 64],
    'weight_decay': [1e-6, 1e-5, 1e-4]
}

best_params = None
best_val_accuracy = 0

for params in ParameterGrid(param_grid):
    print(params)
    # Initialize the model, criterion, and optimizer with the current hyperparameters
    model = TinyVGG5(num_classes=8).to(device)
    model.load_state_dict(state_dict, strict=False)
    optimizer = optim.Adam(model.parameters(), lr=params['lr'], weight_decay=params['weight_decay'])
    criterion = nn.CrossEntropyLoss()

    # Freeze all layers except the final fully connected layer
    for param in model.parameters():
        param.requires_grad = False

    # Unfreeze the final fully connected layer
    for param in model.fc_layers.parameters():
        param.requires_grad = True

    # Update data loaders with the current batch size
    train_loader = torch.utils.data.DataLoader(trainset, batch_size=params['batch_size'], sampler=sampler)
    val_loader = torch.utils.data.DataLoader(testset, batch_size=params['batch_size'], shuffle=False)

    # Train the model
    _, _, _, val_accuracies, _, _ = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=15)

    # Get the best validation accuracy for the current hyperparameters
    max_val_accuracy = max(val_accuracies)
    if max_val_accuracy > best_val_accuracy:
        best_val_accuracy = max_val_accuracy
        best_params = params

print(f'Best Hyperparameters: {best_params}')
print(f'Best Validation Accuracy: {best_val_accuracy}')
# Out:
# {'batch_size': 32, 'lr': 0.0001, 'weight_decay': 1e-06}
# Epoch 1/15, train Loss: 0.0568, train Acc: 98.21%, validation Loss: 1.0427, validation Acc: 78.36%
# Epoch 2/15, train Loss: 0.0511, train Acc: 98.37%, validation Loss: 1.1762, validation Acc: 78.48%
# Epoch 3/15, train Loss: 0.0442, train Acc: 98.70%, validation Loss: 1.0974, validation Acc: 78.53%
# Epoch 4/15, train Loss: 0.0367, train Acc: 98.86%, validation Loss: 1.0646, validation Acc: 78.70%
# Epoch 5/15, train Loss: 0.0366, train Acc: 98.89%, validation Loss: 1.2659, validation Acc: 78.08%
# Epoch 6/15, train Loss: 0.0333, train Acc: 98.89%, validation Loss: 1.2590, validation Acc: 77.93%
# Epoch 7/15, train Loss: 0.0294, train Acc: 99.03%, validation Loss: 1.3024, validation Acc: 78.43%
# Epoch 8/15, train Loss: 0.0300, train Acc: 99.01%, validation Loss: 1.2694, validation Acc: 78.43%
# Epoch 9/15, train Loss: 0.0255, train Acc: 99.14%, validation Loss: 1.2619, validation Acc: 78.38%
# Epoch 10/15, train Loss: 0.0291, train Acc: 99.04%, validation Loss: 1.5518, validation Acc: 78.73%
# Epoch 11/15, train Loss: 0.0235, train Acc: 99.26%, validation Loss: 1.2526, validation Acc: 77.48%
# Epoch 12/15, train Loss: 0.0256, train Acc: 99.15%, validation Loss: 1.3358, validation Acc: 76.87%
# Epoch 13/15, train Loss: 0.0227, train Acc: 99.22%, validation Loss: 1.4840, validation Acc: 77.24%
# Epoch 14/15, train Loss: 0.0231, train Acc: 99.24%, validation Loss: 1.4306, validation Acc: 78.80%
# Epoch 15/15, train Loss: 0.0220, train Acc: 99.27%, validation Loss: 1.4028, validation Acc: 77.66%
# {'batch_size': 32, 'lr': 0.0001, 'weight_decay': 1e-05}
# Epoch 1/15, train Loss: 0.0592, train Acc: 98.06%, validation Loss: 1.0277, validation Acc: 77.70%
# Epoch 2/15, train Loss: 0.0470, train Acc: 98.50%, validation Loss: 1.1061, validation Acc: 78.05%
# Epoch 3/15, train Loss: 0.0417, train Acc: 98.63%, validation Loss: 1.1476, validation Acc: 76.95%
# Epoch 4/15, train Loss: 0.0316, train Acc: 98.91%, validation Loss: 1.4442, validation Acc: 78.35%
# Epoch 5/15, train Loss: 0.0367, train Acc: 98.81%, validation Loss: 1.2536, validation Acc: 78.28%
# Epoch 6/15, train Loss: 0.0358, train Acc: 98.87%, validation Loss: 1.2452, validation Acc: 78.32%
# Epoch 7/15, train Loss: 0.0314, train Acc: 99.03%, validation Loss: 1.2723, validation Acc: 77.63%
# Epoch 8/15, train Loss: 0.0294, train Acc: 99.03%, validation Loss: 1.3208, validation Acc: 78.41%
# Epoch 9/15, train Loss: 0.0261, train Acc: 99.09%, validation Loss: 1.4885, validation Acc: 78.12%
# Epoch 10/15, train Loss: 0.0288, train Acc: 99.01%, validation Loss: 1.3317, validation Acc: 78.53%
# Epoch 11/15, train Loss: 0.0240, train Acc: 99.28%, validation Loss: 1.3793, validation Acc: 78.08%
# Epoch 12/15, train Loss: 0.0281, train Acc: 99.13%, validation Loss: 1.4754, validation Acc: 77.04%
# Epoch 13/15, train Loss: 0.0299, train Acc: 99.01%, validation Loss: 1.5663, validation Acc: 78.94%
# Epoch 14/15, train Loss: 0.0208, train Acc: 99.30%, validation Loss: 1.3870, validation Acc: 78.21%
# Epoch 15/15, train Loss: 0.0201, train Acc: 99.36%, validation Loss: 1.4780, validation Acc: 78.87%
# {'batch_size': 32, 'lr': 0.0001, 'weight_decay': 0.0001}
# Epoch 1/15, train Loss: 0.0599, train Acc: 98.13%, validation Loss: 1.0063, validation Acc: 77.84%
# Epoch 2/15, train Loss: 0.0467, train Acc: 98.45%, validation Loss: 1.1439, validation Acc: 78.62%
# Epoch 3/15, train Loss: 0.0408, train Acc: 98.66%, validation Loss: 1.1339, validation Acc: 77.18%
# Epoch 4/15, train Loss: 0.0412, train Acc: 98.64%, validation Loss: 1.2154, validation Acc: 76.77%
# Epoch 5/15, train Loss: 0.0300, train Acc: 99.05%, validation Loss: 1.2786, validation Acc: 78.72%
# Epoch 6/15, train Loss: 0.0348, train Acc: 98.83%, validation Loss: 1.1812, validation Acc: 77.94%
# Epoch 7/15, train Loss: 0.0302, train Acc: 99.08%, validation Loss: 1.3791, validation Acc: 77.88%
# Epoch 8/15, train Loss: 0.0336, train Acc: 99.01%, validation Loss: 1.1670, validation Acc: 78.05%
# Epoch 9/15, train Loss: 0.0304, train Acc: 98.99%, validation Loss: 1.2289, validation Acc: 78.18%
# Epoch 10/15, train Loss: 0.0312, train Acc: 99.00%, validation Loss: 1.2480, validation Acc: 76.81%
# Epoch 11/15, train Loss: 0.0285, train Acc: 99.09%, validation Loss: 1.2806, validation Acc: 78.62%
# Epoch 12/15, train Loss: 0.0252, train Acc: 99.19%, validation Loss: 1.3204, validation Acc: 77.43%
# Epoch 13/15, train Loss: 0.0231, train Acc: 99.25%, validation Loss: 1.3315, validation Acc: 78.52%
# Epoch 14/15, train Loss: 0.0250, train Acc: 99.20%, validation Loss: 1.1916, validation Acc: 78.32%
# Epoch 15/15, train Loss: 0.0219, train Acc: 99.22%, validation Loss: 1.4124, validation Acc: 78.64%
# {'batch_size': 32, 'lr': 1e-05, 'weight_decay': 1e-06}
# Epoch 1/15, train Loss: 0.0322, train Acc: 98.96%, validation Loss: 1.0530, validation Acc: 78.05%
# Epoch 2/15, train Loss: 0.0263, train Acc: 99.14%, validation Loss: 1.0983, validation Acc: 78.32%
# Epoch 3/15, train Loss: 0.0265, train Acc: 99.29%, validation Loss: 1.0444, validation Acc: 78.52%
# Epoch 4/15, train Loss: 0.0234, train Acc: 99.37%, validation Loss: 1.0744, validation Acc: 78.63%
# Epoch 5/15, train Loss: 0.0211, train Acc: 99.39%, validation Loss: 1.0865, validation Acc: 78.46%
# Epoch 6/15, train Loss: 0.0204, train Acc: 99.37%, validation Loss: 1.0564, validation Acc: 78.42%
# Epoch 7/15, train Loss: 0.0176, train Acc: 99.52%, validation Loss: 1.0913, validation Acc: 78.50%
# Epoch 8/15, train Loss: 0.0178, train Acc: 99.52%, validation Loss: 1.1214, validation Acc: 78.62%
# Epoch 9/15, train Loss: 0.0178, train Acc: 99.52%, validation Loss: 1.1214, validation Acc: 78.79%
# Epoch 10/15, train Loss: 0.0154, train Acc: 99.62%, validation Loss: 1.1564, validation Acc: 78.55%
# Epoch 11/15, train Loss: 0.0149, train Acc: 99.62%, validation Loss: 1.1188, validation Acc: 78.62%
# Epoch 12/15, train Loss: 0.0130, train Acc: 99.68%, validation Loss: 1.1724, validation Acc: 78.66%
# Epoch 13/15, train Loss: 0.0149, train Acc: 99.62%, validation Loss: 1.1287, validation Acc: 78.72%
# Epoch 14/15, train Loss: 0.0135, train Acc: 99.64%, validation Loss: 1.1644, validation Acc: 78.88%
# Epoch 15/15, train Loss: 0.0127, train Acc: 99.68%, validation Loss: 1.1900, validation Acc: 78.94%
# {'batch_size': 32, 'lr': 1e-05, 'weight_decay': 1e-05}
# Epoch 1/15, train Loss: 0.0329, train Acc: 99.02%, validation Loss: 1.0844, validation Acc: 78.31%
# Epoch 2/15, train Loss: 0.0280, train Acc: 99.25%, validation Loss: 1.0798, validation Acc: 78.45%
# Epoch 3/15, train Loss: 0.0218, train Acc: 99.34%, validation Loss: 1.1019, validation Acc: 78.46%
# Epoch 4/15, train Loss: 0.0236, train Acc: 99.31%, validation Loss: 1.0638, validation Acc: 78.74%
# Epoch 5/15, train Loss: 0.0220, train Acc: 99.39%, validation Loss: 1.0827, validation Acc: 78.39%
# Epoch 6/15, train Loss: 0.0182, train Acc: 99.50%, validation Loss: 1.1324, validation Acc: 78.77%
# Epoch 7/15, train Loss: 0.0195, train Acc: 99.48%, validation Loss: 1.1007, validation Acc: 78.76%
# Epoch 8/15, train Loss: 0.0212, train Acc: 99.42%, validation Loss: 1.0546, validation Acc: 78.52%
# Epoch 9/15, train Loss: 0.0201, train Acc: 99.49%, validation Loss: 1.0597, validation Acc: 78.43%
# Epoch 10/15, train Loss: 0.0154, train Acc: 99.59%, validation Loss: 1.1366, validation Acc: 78.95%
# Epoch 11/15, train Loss: 0.0164, train Acc: 99.61%, validation Loss: 1.0981, validation Acc: 78.53%
# Epoch 12/15, train Loss: 0.0141, train Acc: 99.68%, validation Loss: 1.1377, validation Acc: 78.86%
# Epoch 13/15, train Loss: 0.0128, train Acc: 99.69%, validation Loss: 1.1715, validation Acc: 78.88%
# Epoch 14/15, train Loss: 0.0140, train Acc: 99.61%, validation Loss: 1.1385, validation Acc: 78.57%
# Epoch 15/15, train Loss: 0.0134, train Acc: 99.70%, validation Loss: 1.1262, validation Acc: 79.01%
# {'batch_size': 32, 'lr': 1e-05, 'weight_decay': 0.0001}
# Epoch 1/15, train Loss: 0.0302, train Acc: 99.15%, validation Loss: 1.0694, validation Acc: 77.93%
# Epoch 2/15, train Loss: 0.0271, train Acc: 99.19%, validation Loss: 1.0612, validation Acc: 78.12%
# Epoch 3/15, train Loss: 0.0255, train Acc: 99.26%, validation Loss: 1.0605, validation Acc: 78.32%
# Epoch 4/15, train Loss: 0.0261, train Acc: 99.23%, validation Loss: 1.0456, validation Acc: 78.60%
# Epoch 5/15, train Loss: 0.0213, train Acc: 99.38%, validation Loss: 1.0945, validation Acc: 78.76%
# Epoch 6/15, train Loss: 0.0199, train Acc: 99.45%, validation Loss: 1.1126, validation Acc: 78.35%
# Epoch 7/15, train Loss: 0.0191, train Acc: 99.53%, validation Loss: 1.1123, validation Acc: 78.22%
# Epoch 8/15, train Loss: 0.0184, train Acc: 99.53%, validation Loss: 1.0999, validation Acc: 78.52%
# Epoch 9/15, train Loss: 0.0176, train Acc: 99.57%, validation Loss: 1.1105, validation Acc: 78.43%
# Epoch 10/15, train Loss: 0.0188, train Acc: 99.49%, validation Loss: 1.1338, validation Acc: 78.73%
# Epoch 11/15, train Loss: 0.0142, train Acc: 99.65%, validation Loss: 1.1254, validation Acc: 78.76%
# Epoch 12/15, train Loss: 0.0158, train Acc: 99.63%, validation Loss: 1.1212, validation Acc: 78.57%
# Epoch 13/15, train Loss: 0.0154, train Acc: 99.62%, validation Loss: 1.1501, validation Acc: 78.57%
# Epoch 14/15, train Loss: 0.0154, train Acc: 99.63%, validation Loss: 1.1403, validation Acc: 79.03%
# Epoch 15/15, train Loss: 0.0131, train Acc: 99.68%, validation Loss: 1.2100, validation Acc: 78.66%
# {'batch_size': 64, 'lr': 0.0001, 'weight_decay': 1e-06}
# Epoch 1/15, train Loss: 0.0472, train Acc: 98.51%, validation Loss: 0.9632, validation Acc: 77.70%
# Epoch 2/15, train Loss: 0.0385, train Acc: 98.81%, validation Loss: 1.1569, validation Acc: 78.00%
# Epoch 3/15, train Loss: 0.0299, train Acc: 99.05%, validation Loss: 1.1334, validation Acc: 78.79%
# Epoch 4/15, train Loss: 0.0325, train Acc: 99.00%, validation Loss: 1.0885, validation Acc: 78.74%
# Epoch 5/15, train Loss: 0.0249, train Acc: 99.18%, validation Loss: 1.1194, validation Acc: 77.95%
# Epoch 6/15, train Loss: 0.0236, train Acc: 99.23%, validation Loss: 1.2125, validation Acc: 78.48%
# Epoch 7/15, train Loss: 0.0224, train Acc: 99.28%, validation Loss: 1.2768, validation Acc: 79.04%
# Epoch 8/15, train Loss: 0.0199, train Acc: 99.34%, validation Loss: 1.2019, validation Acc: 78.05%
# Epoch 9/15, train Loss: 0.0192, train Acc: 99.39%, validation Loss: 1.3853, validation Acc: 78.77%
# Epoch 10/15, train Loss: 0.0165, train Acc: 99.48%, validation Loss: 1.4319, validation Acc: 78.97%
# Epoch 11/15, train Loss: 0.0188, train Acc: 99.40%, validation Loss: 1.3033, validation Acc: 76.60%
# Epoch 12/15, train Loss: 0.0150, train Acc: 99.52%, validation Loss: 1.4391, validation Acc: 79.12%
# Epoch 13/15, train Loss: 0.0130, train Acc: 99.59%, validation Loss: 1.4671, validation Acc: 77.35%
# Epoch 14/15, train Loss: 0.0203, train Acc: 99.44%, validation Loss: 1.3413, validation Acc: 78.69%
# Epoch 15/15, train Loss: 0.0168, train Acc: 99.45%, validation Loss: 1.5043, validation Acc: 78.29%
# {'batch_size': 64, 'lr': 0.0001, 'weight_decay': 1e-05}
# Epoch 1/15, train Loss: 0.0457, train Acc: 98.54%, validation Loss: 0.9568, validation Acc: 78.15%
# Epoch 2/15, train Loss: 0.0376, train Acc: 98.91%, validation Loss: 1.0457, validation Acc: 77.52%
# Epoch 3/15, train Loss: 0.0319, train Acc: 99.03%, validation Loss: 1.1212, validation Acc: 78.36%
# Epoch 4/15, train Loss: 0.0274, train Acc: 99.19%, validation Loss: 1.1255, validation Acc: 78.62%
# Epoch 5/15, train Loss: 0.0291, train Acc: 99.16%, validation Loss: 1.1157, validation Acc: 77.18%
# Epoch 6/15, train Loss: 0.0208, train Acc: 99.39%, validation Loss: 1.2674, validation Acc: 78.94%
# Epoch 7/15, train Loss: 0.0220, train Acc: 99.31%, validation Loss: 1.2554, validation Acc: 77.81%
# Epoch 8/15, train Loss: 0.0234, train Acc: 99.21%, validation Loss: 1.2257, validation Acc: 78.10%
# Epoch 9/15, train Loss: 0.0218, train Acc: 99.38%, validation Loss: 1.2887, validation Acc: 78.12%
# Epoch 10/15, train Loss: 0.0173, train Acc: 99.49%, validation Loss: 1.2766, validation Acc: 77.10%
# Epoch 11/15, train Loss: 0.0168, train Acc: 99.51%, validation Loss: 1.3642, validation Acc: 78.66%
# Epoch 12/15, train Loss: 0.0155, train Acc: 99.53%, validation Loss: 1.5098, validation Acc: 78.69%
# Epoch 13/15, train Loss: 0.0204, train Acc: 99.33%, validation Loss: 1.3940, validation Acc: 78.59%
# Epoch 14/15, train Loss: 0.0183, train Acc: 99.39%, validation Loss: 1.3232, validation Acc: 78.62%
# Epoch 15/15, train Loss: 0.0170, train Acc: 99.46%, validation Loss: 1.5368, validation Acc: 78.84%
# {'batch_size': 64, 'lr': 0.0001, 'weight_decay': 0.0001}
# Epoch 1/15, train Loss: 0.0449, train Acc: 98.46%, validation Loss: 1.0779, validation Acc: 77.18%
# Epoch 2/15, train Loss: 0.0359, train Acc: 98.93%, validation Loss: 1.1086, validation Acc: 77.48%
# Epoch 3/15, train Loss: 0.0373, train Acc: 98.92%, validation Loss: 1.0074, validation Acc: 77.88%
# Epoch 4/15, train Loss: 0.0265, train Acc: 99.19%, validation Loss: 1.1605, validation Acc: 77.84%
# Epoch 5/15, train Loss: 0.0299, train Acc: 99.07%, validation Loss: 1.2700, validation Acc: 78.24%
# Epoch 6/15, train Loss: 0.0260, train Acc: 99.19%, validation Loss: 1.1791, validation Acc: 78.72%
# Epoch 7/15, train Loss: 0.0237, train Acc: 99.26%, validation Loss: 1.3170, validation Acc: 78.60%
# Epoch 8/15, train Loss: 0.0202, train Acc: 99.36%, validation Loss: 1.2933, validation Acc: 78.12%
# Epoch 9/15, train Loss: 0.0226, train Acc: 99.36%, validation Loss: 1.3350, validation Acc: 78.66%
# Epoch 10/15, train Loss: 0.0179, train Acc: 99.50%, validation Loss: 1.3480, validation Acc: 78.72%
# Epoch 11/15, train Loss: 0.0170, train Acc: 99.46%, validation Loss: 1.2721, validation Acc: 78.48%
# Epoch 12/15, train Loss: 0.0203, train Acc: 99.36%, validation Loss: 1.3013, validation Acc: 78.83%
# Epoch 13/15, train Loss: 0.0174, train Acc: 99.48%, validation Loss: 1.4341, validation Acc: 78.55%
# Epoch 14/15, train Loss: 0.0177, train Acc: 99.45%, validation Loss: 1.3446, validation Acc: 78.03%
# Epoch 15/15, train Loss: 0.0183, train Acc: 99.44%, validation Loss: 1.3411, validation Acc: 78.05%
# {'batch_size': 64, 'lr': 1e-05, 'weight_decay': 1e-06}
# Epoch 1/15, train Loss: 0.0350, train Acc: 99.03%, validation Loss: 1.0662, validation Acc: 78.08%
# Epoch 2/15, train Loss: 0.0261, train Acc: 99.22%, validation Loss: 1.0529, validation Acc: 77.93%
# Epoch 3/15, train Loss: 0.0244, train Acc: 99.30%, validation Loss: 1.0679, validation Acc: 78.48%
# Epoch 4/15, train Loss: 0.0231, train Acc: 99.32%, validation Loss: 1.0714, validation Acc: 78.49%
# Epoch 5/15, train Loss: 0.0201, train Acc: 99.45%, validation Loss: 1.0845, validation Acc: 78.60%
# Epoch 6/15, train Loss: 0.0202, train Acc: 99.45%, validation Loss: 1.0910, validation Acc: 78.60%
# Epoch 7/15, train Loss: 0.0179, train Acc: 99.48%, validation Loss: 1.0755, validation Acc: 78.59%
# Epoch 8/15, train Loss: 0.0181, train Acc: 99.48%, validation Loss: 1.0858, validation Acc: 78.29%
# Epoch 9/15, train Loss: 0.0208, train Acc: 99.47%, validation Loss: 1.0907, validation Acc: 78.43%
# Epoch 10/15, train Loss: 0.0154, train Acc: 99.61%, validation Loss: 1.1046, validation Acc: 78.52%
# Epoch 11/15, train Loss: 0.0161, train Acc: 99.62%, validation Loss: 1.1169, validation Acc: 78.88%
# Epoch 12/15, train Loss: 0.0147, train Acc: 99.62%, validation Loss: 1.0851, validation Acc: 78.98%
# Epoch 13/15, train Loss: 0.0132, train Acc: 99.68%, validation Loss: 1.1429, validation Acc: 79.04%
# Epoch 14/15, train Loss: 0.0155, train Acc: 99.56%, validation Loss: 1.1382, validation Acc: 78.98%
# Epoch 15/15, train Loss: 0.0156, train Acc: 99.67%, validation Loss: 1.1298, validation Acc: 78.86%
# {'batch_size': 64, 'lr': 1e-05, 'weight_decay': 1e-05}
# Epoch 1/15, train Loss: 0.0336, train Acc: 99.02%, validation Loss: 1.0742, validation Acc: 78.00%
# Epoch 2/15, train Loss: 0.0273, train Acc: 99.25%, validation Loss: 1.0644, validation Acc: 78.31%
# Epoch 3/15, train Loss: 0.0251, train Acc: 99.28%, validation Loss: 1.0673, validation Acc: 78.19%
# Epoch 4/15, train Loss: 0.0210, train Acc: 99.48%, validation Loss: 1.1252, validation Acc: 78.50%
# Epoch 5/15, train Loss: 0.0220, train Acc: 99.36%, validation Loss: 1.0841, validation Acc: 78.53%
# Epoch 6/15, train Loss: 0.0199, train Acc: 99.49%, validation Loss: 1.0846, validation Acc: 78.63%
# Epoch 7/15, train Loss: 0.0208, train Acc: 99.44%, validation Loss: 1.0706, validation Acc: 78.62%
# Epoch 8/15, train Loss: 0.0177, train Acc: 99.52%, validation Loss: 1.1116, validation Acc: 78.76%
# Epoch 9/15, train Loss: 0.0173, train Acc: 99.56%, validation Loss: 1.0993, validation Acc: 78.77%
# Epoch 10/15, train Loss: 0.0163, train Acc: 99.61%, validation Loss: 1.0930, validation Acc: 78.70%
# Epoch 11/15, train Loss: 0.0150, train Acc: 99.64%, validation Loss: 1.1168, validation Acc: 78.83%
# Epoch 12/15, train Loss: 0.0161, train Acc: 99.58%, validation Loss: 1.1456, validation Acc: 78.88%
# Epoch 13/15, train Loss: 0.0136, train Acc: 99.64%, validation Loss: 1.1333, validation Acc: 78.74%
# Epoch 14/15, train Loss: 0.0142, train Acc: 99.67%, validation Loss: 1.1313, validation Acc: 78.73%
# Epoch 15/15, train Loss: 0.0146, train Acc: 99.58%, validation Loss: 1.1115, validation Acc: 78.73%
# {'batch_size': 64, 'lr': 1e-05, 'weight_decay': 0.0001}
# Epoch 1/15, train Loss: 0.0347, train Acc: 99.04%, validation Loss: 1.0230, validation Acc: 77.56%
# Epoch 2/15, train Loss: 0.0256, train Acc: 99.30%, validation Loss: 1.0781, validation Acc: 78.31%
# Epoch 3/15, train Loss: 0.0266, train Acc: 99.27%, validation Loss: 1.0524, validation Acc: 78.18%
# Epoch 4/15, train Loss: 0.0217, train Acc: 99.37%, validation Loss: 1.0826, validation Acc: 78.74%
# Epoch 5/15, train Loss: 0.0209, train Acc: 99.44%, validation Loss: 1.0854, validation Acc: 78.43%
# Epoch 6/15, train Loss: 0.0214, train Acc: 99.45%, validation Loss: 1.0692, validation Acc: 78.41%
# Epoch 7/15, train Loss: 0.0217, train Acc: 99.46%, validation Loss: 1.0817, validation Acc: 78.67%
# Epoch 8/15, train Loss: 0.0186, train Acc: 99.53%, validation Loss: 1.1008, validation Acc: 78.81%
# Epoch 9/15, train Loss: 0.0171, train Acc: 99.48%, validation Loss: 1.1039, validation Acc: 78.55%
# Epoch 10/15, train Loss: 0.0169, train Acc: 99.53%, validation Loss: 1.0883, validation Acc: 78.80%
# Epoch 11/15, train Loss: 0.0182, train Acc: 99.57%, validation Loss: 1.0602, validation Acc: 78.79%
# Epoch 12/15, train Loss: 0.0155, train Acc: 99.62%, validation Loss: 1.1257, validation Acc: 78.97%
# Epoch 13/15, train Loss: 0.0144, train Acc: 99.61%, validation Loss: 1.1229, validation Acc: 78.84%
# Epoch 14/15, train Loss: 0.0145, train Acc: 99.62%, validation Loss: 1.1224, validation Acc: 78.83%
# Epoch 15/15, train Loss: 0.0130, train Acc: 99.68%, validation Loss: 1.1205, validation Acc: 78.72%
# Best Hyperparameters: {'batch_size': 64, 'lr': 0.0001, 'weight_decay': 1e-06}
# Best Validation Accuracy: 79.12382025637413

# %% [markdown]
# # **Train with best transfer learning setting**

# %%
model = TinyVGG5(num_classes=8).to(device)
model.load_state_dict(state_dict, strict=False)

optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-6)
criterion = nn.CrossEntropyLoss()

# Freeze all layers except the final fully connected layer
for param in model.parameters():
    param.requires_grad = False

# Unfreeze the final fully connected layer
for param in model.fc_layers.parameters():
    param.requires_grad = True

train_loader = torch.utils.data.DataLoader(trainset, batch_size=64, sampler=sampler)
val_loader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

train_losses, val_losses, train_accuracies, val_accuracies, all_preds, all_labels = train_model(model, train_loader, test_loader, criterion, optimizer, 40)

plot_results(train_losses, val_losses, train_accuracies, val_accuracies, 40, all_preds, all_labels)
# Out:
# Epoch 1/40, train Loss: 0.0472, train Acc: 98.49%, validation Loss: 1.0667, validation Acc: 78.45%
# Epoch 2/40, train Loss: 0.0367, train Acc: 98.85%, validation Loss: 1.1149, validation Acc: 77.76%
# Epoch 3/40, train Loss: 0.0313, train Acc: 99.06%, validation Loss: 1.0628, validation Acc: 78.39%
# Epoch 4/40, train Loss: 0.0317, train Acc: 98.98%, validation Loss: 1.1472, validation Acc: 78.48%
# Epoch 5/40, train Loss: 0.0244, train Acc: 99.25%, validation Loss: 1.2260, validation Acc: 77.88%
# Epoch 6/40, train Loss: 0.0223, train Acc: 99.32%, validation Loss: 1.2386, validation Acc: 78.70%
# Epoch 7/40, train Loss: 0.0225, train Acc: 99.26%, validation Loss: 1.2730, validation Acc: 78.64%
# Epoch 8/40, train Loss: 0.0217, train Acc: 99.33%, validation Loss: 1.3190, validation Acc: 78.45%
# Epoch 9/40, train Loss: 0.0188, train Acc: 99.39%, validation Loss: 1.3785, validation Acc: 78.87%
# Epoch 10/40, train Loss: 0.0209, train Acc: 99.38%, validation Loss: 1.4646, validation Acc: 77.24%
# Epoch 11/40, train Loss: 0.0203, train Acc: 99.35%, validation Loss: 1.3460, validation Acc: 78.93%
# Epoch 12/40, train Loss: 0.0156, train Acc: 99.56%, validation Loss: 1.3561, validation Acc: 78.91%
# Epoch 13/40, train Loss: 0.0167, train Acc: 99.45%, validation Loss: 1.4461, validation Acc: 78.91%
# Epoch 14/40, train Loss: 0.0152, train Acc: 99.52%, validation Loss: 1.4851, validation Acc: 78.64%
# Epoch 15/40, train Loss: 0.0174, train Acc: 99.39%, validation Loss: 1.4759, validation Acc: 78.25%
# Epoch 16/40, train Loss: 0.0171, train Acc: 99.45%, validation Loss: 1.5323, validation Acc: 78.81%
# Epoch 17/40, train Loss: 0.0125, train Acc: 99.59%, validation Loss: 1.5756, validation Acc: 78.93%
# Epoch 18/40, train Loss: 0.0151, train Acc: 99.51%, validation Loss: 1.4027, validation Acc: 78.46%
# Epoch 19/40, train Loss: 0.0143, train Acc: 99.48%, validation Loss: 1.6490, validation Acc: 79.04%
# Epoch 20/40, train Loss: 0.0129, train Acc: 99.57%, validation Loss: 1.4625, validation Acc: 78.53%
# Epoch 21/40, train Loss: 0.0144, train Acc: 99.55%, validation Loss: 1.5128, validation Acc: 78.35%
# Epoch 22/40, train Loss: 0.0120, train Acc: 99.58%, validation Loss: 1.7704, validation Acc: 78.98%
# Epoch 23/40, train Loss: 0.0117, train Acc: 99.61%, validation Loss: 1.6195, validation Acc: 79.08%
# Epoch 24/40, train Loss: 0.0145, train Acc: 99.55%, validation Loss: 1.6750, validation Acc: 78.94%
# Epoch 25/40, train Loss: 0.0097, train Acc: 99.66%, validation Loss: 1.7773, validation Acc: 78.88%
# Epoch 26/40, train Loss: 0.0164, train Acc: 99.49%, validation Loss: 1.6268, validation Acc: 78.84%
# Epoch 27/40, train Loss: 0.0090, train Acc: 99.73%, validation Loss: 1.6493, validation Acc: 79.17%
# Epoch 28/40, train Loss: 0.0104, train Acc: 99.66%, validation Loss: 1.7592, validation Acc: 78.33%
# Epoch 29/40, train Loss: 0.0091, train Acc: 99.71%, validation Loss: 1.7892, validation Acc: 78.36%
# Epoch 30/40, train Loss: 0.0098, train Acc: 99.69%, validation Loss: 1.7000, validation Acc: 78.52%
# Epoch 31/40, train Loss: 0.0104, train Acc: 99.64%, validation Loss: 1.7842, validation Acc: 78.49%
# Epoch 32/40, train Loss: 0.0110, train Acc: 99.61%, validation Loss: 1.8108, validation Acc: 78.74%
# Epoch 33/40, train Loss: 0.0093, train Acc: 99.69%, validation Loss: 1.8276, validation Acc: 78.48%
# Epoch 34/40, train Loss: 0.0094, train Acc: 99.70%, validation Loss: 1.7847, validation Acc: 78.53%
# Epoch 35/40, train Loss: 0.0076, train Acc: 99.76%, validation Loss: 1.9711, validation Acc: 78.83%
# Epoch 36/40, train Loss: 0.0100, train Acc: 99.65%, validation Loss: 1.7947, validation Acc: 78.81%
# Epoch 37/40, train Loss: 0.0074, train Acc: 99.76%, validation Loss: 1.9842, validation Acc: 78.07%
# Epoch 38/40, train Loss: 0.0104, train Acc: 99.65%, validation Loss: 2.0178, validation Acc: 78.31%
# Epoch 39/40, train Loss: 0.0096, train Acc: 99.67%, validation Loss: 2.0414, validation Acc: 78.64%
# Epoch 40/40, train Loss: 0.0111, train Acc: 99.65%, validation Loss: 1.6443, validation Acc: 78.56%

# %% [markdown]
# # Evaluation

# %%
correct = 0
total = 0

num_classes = 8
classes = trainset.classes

# Lists to store all labels and predictions for confusion matrix
all_labels = []
all_preds = []

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # Append labels and predictions for confusion matrix
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(predicted.cpu().numpy())

print(f'Accuracy of the network on the test images: {100 * correct / total:.2f}%')

# Test the model (accuracy per class)
class_correct = list(0. for _ in range(num_classes))
class_total = list(0. for _ in range(num_classes))

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(len(labels)):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

for i in range(num_classes):
    print(f'Accuracy of {classes[i]}: {100 * class_correct[i] / class_total[i]:.2f}%')

# Calculate the confusion matrix
cm = confusion_matrix(all_labels, all_preds)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=trainset.classes)
disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.show()
# Out:
# Accuracy of the network on the test images: 78.56%
# Accuracy of anger: 65.22%
# Accuracy of contempt: 23.53%
# Accuracy of disgust: 42.11%
# Accuracy of fear: 41.92%
# Accuracy of happiness: 88.62%
# Accuracy of neutral: 85.14%
# Accuracy of sadness: 54.91%
# Accuracy of surprise: 83.44%

# %%
# Save the model
torch.save(model.state_dict(), 'tiny_VGG_transfer_learning.pth')
